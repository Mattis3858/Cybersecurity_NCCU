# %% [markdown]
# # Homework
#
# Take a look at this code. Since it is the first homework, we will guide how to finish it. Make sure you answer all the quesions in <font color="red">red</font> color. The answer is either an output of your code (for example, a figure, a data table), or a paragraph.

# %% [markdown]
# # ZeroAccess

# %% [markdown]
# (Colab AI) ZeroAccess is a type of ransomware that was first discovered in 2016. It is known for its ability to encrypt files on a victim's computer and then demand a ransom payment in exchange for the decryption key. ZeroAccess is typically distributed through phishing emails or malicious websites.

# %% [markdown]
# ## Data Tables

# %%
# get data from github

import requests

url = 'https://github.com/hsiaom26/DS4CS-24/raw/main/data/zeroaccess.zip'

response = requests.get(url)

if response.status_code == 200:
    # Open the file for writing
    with open('zeroaccess.zip', 'wb') as f:
        # Write the response content to the file
        f.write(response.content)
else:
    print('Error: Failed to download the file')

# %%
# !unzip zeroaccess.zip
# Out:
# Archive:  zeroaccess.zip
# replace zeroaccess/state-internets.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace zeroaccess/zeroaccess.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace zeroaccess/county-data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

z_df = pd.read_csv('zeroaccess/zeroaccess.csv')
s_df = pd.read_csv('zeroaccess/state-internets.csv')
c_df = pd.read_csv('zeroaccess/county-data.csv')

# %%
# the latitude and longitude of the observed ZeroAccess attacks
z_df
# Out:
#             lat      long
# 0      -10.0000  -55.0000
# 1       38.0888  -78.5592
# 2       38.9990  -84.6266
# 3       48.6210    7.4944
# 4       43.2342  -86.2484
# ...         ...       ...
# 808441  42.9634  -85.6681
# 808442  43.2167  -79.7500
# 808443  43.8833  -79.7333
# 808444 -33.8833  151.2167
# 808445  40.5982  -83.1425
#
# [808446 rows x 2 columns]

# %%
# some data of US states
s_df
# Out:
#                    state  population  internet
# 0                Alabama     4758191   3092273
# 1                Arizona     6665093   5230474
# 2               Arkansas     2919815   1949869
# 3             California    37350092  29758896
# 4               Colorado     5077553   4058749
# 5            Connecticut     3555261   3074229
# 6               Delaware      894424    719500
# 7   District of Columbia      605959    463503
# 8                Florida    18732783  14764418
# 9                Georgia     9932505   7597608
# 10                 Idaho     1562046   1284500
# 11              Illinois    13046084  10243294
# 12               Indiana     6490613   4770355
# 13                  Iowa     3039465   2354728
# 14                Kansas     2848369   2248721
# 15              Kentucky     4359450   2997542
# 16             Louisiana     4539283   3071973
# 17                 Maine     1332155   1102933
# 18              Maryland     5759373   4737650
# 19         Massachusetts     6662878   5745853
# 20              Michigan    10074498   7899843
# 21             Minnesota     5321556   4370006
# 22           Mississippi     2983018   1769430
# 23              Missouri     6050503   4380156
# 24               Montana      985235    725139
# 25              Nebraska     1815500   1455917
# 26                Nevada     2670861   2137074
# 27         New Hampshire     1338495   1205558
# 28            New Jersey     8799248   7728426
# 29            New Mexico     2030790   1380358
# 30              New York    19746813  16091772
# 31        North Carolina     9479467   6809315
# 32          North Dakota      653642    496207
# 33                  Ohio    11663946   8949773
# 34              Oklahoma     3725797   2530656
# 35                Oregon     3865861   3327971
# 36          Pennsylvania    12737230   9909482
# 37          Rhode Island     1064277    861596
# 38        South Carolina     4609176   3086634
# 39          South Dakota      820920    598832
# 40             Tennessee     6362421   4638409
# 41                 Texas    25042738  17176661
# 42                  Utah     2813835   2465247
# 43               Vermont      628294    513123
# 44              Virginia     7965428   6193567
# 45            Washington     6734229   5772919
# 46         West Virginia     1838901   1296905
# 47             Wisconsin     5714200   4744417
# 48               Wyoming      549990    436437

# %%
# some other info of (sub-)regions in US states
c_df
# Out:
#       subregion          region     pop  income   ipaddr  ufo2010
# 0     abbeville  south carolina   25101   34670    30330        2
# 1        acadia       louisiana   61912   37970    38203        6
# 2      accomack        virginia   33341   41595    41338        2
# 3           ada           idaho  409061   55304  1035427       59
# 4         adair            iowa    7481   47623     3762        0
# ...         ...             ...     ...     ...      ...      ...
# 3067       yuma         arizona  200022   41441    99991       53
# 3068       yuma        colorado   10119   44991     7662        1
# 3069     zapata           texas   14290   26009     3833        0
# 3070     zavala           texas   11961   23952      545        1
# 3071    ziebach    south dakota    2869   27917     1277        0
#
# [3072 rows x 6 columns]

# %% [markdown]
# ## Plot on a Map

# %%
# plot zeroAccess infection instances on a map
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

ax.scatter(z_df.long, z_df.lat, alpha = 0.1, s = 1, label = "zeroAccess")
ax.set_xlim((-180, 180))
ax.set_ylim((-90, 90))

plt.xlabel("Latitude and longitude")
plt.ylabel("Latitude and longitude")
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# ## Q1
# <font color="red">Try to plot US-only data (i.e., show a map with using only US data).</font> We need a 3rd-party database that can help us to convert the latitude and longitude information in `z_df` to the corresponding nation (and US state).
#
# `reverse_geocoder`'s rearch function can accept a list of (latitude,longitude) and return a list of country informaion.

# %%
# !pip install reverse_geocoder
# Out:
# Requirement already satisfied: reverse_geocoder in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from reverse_geocoder) (1.25.2)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from reverse_geocoder) (1.11.4)

# %%
# reverse_geocoder example
# given a list of (latitude,longitude),
# a list of information (in python dictionary format) will be returned.
# we need 'cc' (country code) and 'admin1' (region) for later analysis

import reverse_geocoder
reverse_geocoder.search([(-10, -55), (38.0888, -78.5592)])
# Out:
# [{'lat': '-9.87556',
#   'lon': '-56.08611',
#   'name': 'Alta Floresta',
#   'admin1': 'Mato Grosso',
#   'admin2': 'Alta Floresta',
#   'cc': 'BR'},
#  {'lat': '38.02931',
#   'lon': '-78.47668',
#   'name': 'Charlottesville',
#   'admin1': 'Virginia',
#   'admin2': 'City of Charlottesville',
#   'cc': 'US'}]

# %%
import reverse_geocoder

def get_country_and_state_batch(df_of_lat_lng):
    """
    Get the country info from a dataframe containing (latitude, longitude).

    Returns:
        A dataFrame with info from reverse_geocoder
    """

    # Get results from reverse_geocoder
    list_of_lat_lng = list(zip(df_of_lat_lng.lat, df_of_lat_lng.long))
    result_dict_li = reverse_geocoder.search(list_of_lat_lng)
    return pd.DataFrame(result_dict_li).drop(["lat", "lon"], axis = 1)

# %%
z_df.head(10) # example
# Out:
#        lat      long
# 0 -10.0000  -55.0000
# 1  38.0888  -78.5592
# 2  38.9990  -84.6266
# 3  48.6210    7.4944
# 4  43.2342  -86.2484
# 5  47.0000   20.0000
# 6  44.8012  -68.7778
# 7  51.3333    1.4333
# 8  36.0580  -88.8253
# 9  20.6000 -100.3833

# %%
_df = get_country_and_state_batch(z_df.head(10)) # this example hass only 10 rows
_df
# Out:
#                     name       admin1                   admin2  cc
# 0          Alta Floresta  Mato Grosso            Alta Floresta  BR
# 1        Charlottesville     Virginia  City of Charlottesville  US
# 2               Florence     Kentucky             Boone County  US
# 3             Marlenheim       Alsace  Departement du Bas-Rhin  FR
# 4               Muskegon     Michigan          Muskegon County  US
# 5                 Kocser         Pest                           HU
# 6                 Bangor        Maine         Penobscot County  US
# 7               Ramsgate      England                     Kent  GB
# 8               Bradford    Tennessee            Gibson County  US
# 9  Santiago de Queretaro    Queretaro                Queretaro  MX

# %%
# merge latitude, longitude and contry info together
df = z_df.merge(_df, left_index = True, right_index = True)
df
# Out:
#        lat      long                   name       admin1  \
# 0 -10.0000  -55.0000          Alta Floresta  Mato Grosso
# 1  38.0888  -78.5592        Charlottesville     Virginia
# 2  38.9990  -84.6266               Florence     Kentucky
# 3  48.6210    7.4944             Marlenheim       Alsace
# 4  43.2342  -86.2484               Muskegon     Michigan
# 5  47.0000   20.0000                 Kocser         Pest
# 6  44.8012  -68.7778                 Bangor        Maine
# 7  51.3333    1.4333               Ramsgate      England
# 8  36.0580  -88.8253               Bradford    Tennessee
# 9  20.6000 -100.3833  Santiago de Queretaro    Queretaro
#
#                     admin2  cc
# 0            Alta Floresta  BR
# 1  City of Charlottesville  US
# 2             Boone County  US
# 3  Departement du Bas-Rhin  FR
# 4          Muskegon County  US
# 5                           HU
# 6         Penobscot County  US
# 7                     Kent  GB
# 8            Gibson County  US
# 9                Queretaro  MX

# %% [markdown]
# Modify the above example, and only include US data in entire z_df (note that the example shown above only has 10 rows). Lets assume the the dataframe is z_us_df.

# %%
# Your code here!
_df = get_country_and_state_batch(z_df)
z_us_df = z_df[_df['cc'] == 'US']
z_us_df = z_us_df.merge(_df, left_index = True, right_index = True)

z_us_df
# z_us_df
# def get_country_and_state_batch(df_of_lat_lng):
#     list_of_lat_lng = list(zip(df_of_lat_lng.lat, df_of_lat_lng.long))
#     result_dict_li = reverse_geocoder.search(list_of_lat_lng)

#     us_data = [result for result in result_dict_li if result['cc'] == 'US']

#     return pd.DataFrame(us_data).drop(["lat", "lon"], axis = 1)
# Out:
#             lat     long             name         admin1  \
# 1       38.0888 -78.5592  Charlottesville       Virginia
# 2       38.9990 -84.6266         Florence       Kentucky
# 4       43.2342 -86.2484         Muskegon       Michigan
# 6       44.8012 -68.7778           Bangor          Maine
# 8       36.0580 -88.8253         Bradford      Tennessee
# ...         ...      ...              ...            ...
# 808436  42.7495 -73.5951      Poestenkill       New York
# 808437  33.7490 -84.3880          Atlanta        Georgia
# 808438  43.7173 -71.7163         Plymouth  New Hampshire
# 808441  42.9634 -85.6681     Grand Rapids       Michigan
# 808445  40.5982 -83.1425           Marion           Ohio
#
#                          admin2  cc
# 1       City of Charlottesville  US
# 2                  Boone County  US
# 4               Muskegon County  US
# 6              Penobscot County  US
# 8                 Gibson County  US
# ...                         ...  ..
# 808436        Rensselaer County  US
# 808437            Fulton County  US
# 808438           Grafton County  US
# 808441              Kent County  US
# 808445            Marion County  US
#
# [280493 rows x 6 columns]

# %% [markdown]
# Now you can plot the US-only map below.

# %%
# Your code here!
# plot zeroAccess infection instances on a map
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

ax.scatter(z_us_df.long, z_us_df.lat, alpha = 0.1, s = 1, label = "zeroAccess")
ax.set_xlim((-170, -60))
ax.set_ylim((15, 75))

plt.xlabel("Latitude and longitude")
plt.ylabel("Latitude and longitude")
plt.legend(loc='upper left')

plt.show()
# plot zeroAccess infection instances on a map as below

# %% [markdown]
# ## Q2
# <font color="red">Aggregate the number of ZeroAccess attakcs per state (the state name is in 'admin1' column).</font>
#
# Hint: try `value_counts()` function of dataframe, and you can `rename()` a column name for better representation. An example data table is shown, try to output a dataframe as shown below.

# %%
# Your code here!

# count the value of admin1 of each state
z_state_counts = z_us_df['admin1'].value_counts()
z_state_counts
# turn into a dataframe
z_state_df = pd.DataFrame(z_state_counts)

# replace admin1 as ZeroAccess
z_state_df.rename(columns={'admin1': 'ZeroAccess'}, inplace=True)
z_state_df
# z_state_df
# Out:
#                   ZeroAccess
# California             28162
# Texas                  22746
# Florida                17414
# New York               16207
# Kansas                 15241
# Pennsylvania           11020
# Ohio                   10832
# Georgia                10386
# Illinois               10312
# North Carolina          8989
# Michigan                8362
# New Jersey              8066
# Arizona                 5928
# Virginia                5753
# Washington              5631
# Massachusetts           5597
# Missouri                5561
# Indiana                 5418
# Tennessee               5248
# Maryland                5195
# Wisconsin               4965
# Alabama                 4779
# Kentucky                4504
# Minnesota               4470
# South Carolina          4460
# Colorado                4413
# Louisiana               4372
# Oklahoma                3225
# Connecticut             2924
# Arkansas                2738
# Oregon                  2686
# Mississippi             2600
# Iowa                    2559
# Nevada                  2283
# Utah                    1830
# West Virginia           1718
# Nebraska                1552
# New Mexico              1532
# Maine                   1227
# Idaho                   1147
# New Hampshire           1145
# Rhode Island             992
# Hawaii                   983
# Montana                  889
# Wyoming                  757
# South Dakota             750
# Delaware                 740
# North Dakota             634
# Washington, D.C.         621
# Alaska                   533
# Vermont                  397

# %% [markdown]
# ## Q3
#
# <font color="red">Show the ZeroAccess info per city/county in a state. Which city/county suffers from the ZeroAccess attack the most? (You should output a data table and sort it by the number of attacks, and point out which county has highest attack?)</font>
#
# Note that the city/county name is in 'admin2' column, and some city name may exist in differnt state (so that you cannot simply count the number of attacks by `admin2.value_counts()`)
#
# Hint: try `groupby()`, `count()` functions on a dataframe.

# %%
# Your code here!

# Grouping by 'admin1' and 'admin2', and getting the size
city_counts = z_us_df.groupby(['admin1', 'admin2']).size().reset_index(name='cc')

# sort city counts by descending order
city_counts_sorted = city_counts.sort_values(by='cc', ascending=False)
# set the index as [admin1, admin2] instead of numbers
city_counts_sorted = city_counts_sorted.set_index(['admin1', 'admin2'])
city_counts_sorted
# Out:
#                                   cc
# admin1     admin2
# Kansas     Marion County       12655
# California Los Angeles County   8031
# Texas      Harris County        4591
# Illinois   Cook County          4414
# Arizona    Maricopa County      4228
# ...                              ...
# Kansas     Republic County         1
# Vermont    Grand Isle County       1
# Virginia   Grayson County          1
# Kansas     Stanton County          1
#            Trego County            1
#
# [2969 rows x 1 columns]

# %% [markdown]
# ## Q4
#
# <font color="red">Does the attack occurance in each state relate to state population or the number of internet users? Using a bar char to demonstrate it!</font>
#
# Hint: you need to first aggrgate 'population' and 'internet' info in `s_df` to `z_state_df`. The dataframe row index should be the state name. And then, you plot 'population', 'internet' and 'ZeroAccess' data in a bar chart as shown below.

# %%
pop_state_df = s_df.copy()
pop_state_df.state = pop_state_df.state.apply(lambda x: 'Washington, D.C.' if x == 'District of Columbia' else x) # District of Columbia -> Washington, D.C.
pop_state_df = pop_state_df.set_index('state')
pop_state_df
# Out:
#                   population  internet
# state
# Alabama              4758191   3092273
# Arizona              6665093   5230474
# Arkansas             2919815   1949869
# California          37350092  29758896
# Colorado             5077553   4058749
# Connecticut          3555261   3074229
# Delaware              894424    719500
# Washington, D.C.      605959    463503
# Florida             18732783  14764418
# Georgia              9932505   7597608
# Idaho                1562046   1284500
# Illinois            13046084  10243294
# Indiana              6490613   4770355
# Iowa                 3039465   2354728
# Kansas               2848369   2248721
# Kentucky             4359450   2997542
# Louisiana            4539283   3071973
# Maine                1332155   1102933
# Maryland             5759373   4737650
# Massachusetts        6662878   5745853
# Michigan            10074498   7899843
# Minnesota            5321556   4370006
# Mississippi          2983018   1769430
# Missouri             6050503   4380156
# Montana               985235    725139
# Nebraska             1815500   1455917
# Nevada               2670861   2137074
# New Hampshire        1338495   1205558
# New Jersey           8799248   7728426
# New Mexico           2030790   1380358
# New York            19746813  16091772
# North Carolina       9479467   6809315
# North Dakota          653642    496207
# Ohio                11663946   8949773
# Oklahoma             3725797   2530656
# Oregon               3865861   3327971
# Pennsylvania        12737230   9909482
# Rhode Island         1064277    861596
# South Carolina       4609176   3086634
# South Dakota          820920    598832
# Tennessee            6362421   4638409
# Texas               25042738  17176661
# Utah                 2813835   2465247
# Vermont               628294    513123
# Virginia             7965428   6193567
# Washington           6734229   5772919
# West Virginia        1838901   1296905
# Wisconsin            5714200   4744417
# Wyoming               549990    436437

# %%
# another way to concate two dataframes
# note that some information is missing!
# try dropna() to remove rows with missing value

compare_df = pd.concat([z_state_df, pop_state_df], join="outer", sort=False, axis=1)
compare_df
# Out:
#                   ZeroAccess  population    internet
# California             28162  37350092.0  29758896.0
# Texas                  22746  25042738.0  17176661.0
# Florida                17414  18732783.0  14764418.0
# New York               16207  19746813.0  16091772.0
# Kansas                 15241   2848369.0   2248721.0
# Pennsylvania           11020  12737230.0   9909482.0
# Ohio                   10832  11663946.0   8949773.0
# Georgia                10386   9932505.0   7597608.0
# Illinois               10312  13046084.0  10243294.0
# North Carolina          8989   9479467.0   6809315.0
# Michigan                8362  10074498.0   7899843.0
# New Jersey              8066   8799248.0   7728426.0
# Arizona                 5928   6665093.0   5230474.0
# Virginia                5753   7965428.0   6193567.0
# Washington              5631   6734229.0   5772919.0
# Massachusetts           5597   6662878.0   5745853.0
# Missouri                5561   6050503.0   4380156.0
# Indiana                 5418   6490613.0   4770355.0
# Tennessee               5248   6362421.0   4638409.0
# Maryland                5195   5759373.0   4737650.0
# Wisconsin               4965   5714200.0   4744417.0
# Alabama                 4779   4758191.0   3092273.0
# Kentucky                4504   4359450.0   2997542.0
# Minnesota               4470   5321556.0   4370006.0
# South Carolina          4460   4609176.0   3086634.0
# Colorado                4413   5077553.0   4058749.0
# Louisiana               4372   4539283.0   3071973.0
# Oklahoma                3225   3725797.0   2530656.0
# Connecticut             2924   3555261.0   3074229.0
# Arkansas                2738   2919815.0   1949869.0
# Oregon                  2686   3865861.0   3327971.0
# Mississippi             2600   2983018.0   1769430.0
# Iowa                    2559   3039465.0   2354728.0
# Nevada                  2283   2670861.0   2137074.0
# Utah                    1830   2813835.0   2465247.0
# West Virginia           1718   1838901.0   1296905.0
# Nebraska                1552   1815500.0   1455917.0
# New Mexico              1532   2030790.0   1380358.0
# Maine                   1227   1332155.0   1102933.0
# Idaho                   1147   1562046.0   1284500.0
# New Hampshire           1145   1338495.0   1205558.0
# Rhode Island             992   1064277.0    861596.0
# Hawaii                   983         NaN         NaN
# Montana                  889    985235.0    725139.0
# Wyoming                  757    549990.0    436437.0
# South Dakota             750    820920.0    598832.0
# Delaware                 740    894424.0    719500.0
# North Dakota             634    653642.0    496207.0
# Washington, D.C.         621    605959.0    463503.0
# Alaska                   533         NaN         NaN
# Vermont                  397    628294.0    513123.0

# %%
compare_df[["ZeroAccess", "population", "internet"]].dropna().plot.bar(rot=0, figsize=(16,3))
plt.xticks(rotation=90)
plt.show()

# %%
# try to normalize each column for better presentation

# Your code here!
# normalized_df = (compare_df - compare_df.min()) / (compare_df.max() - compare_df.min())

# Calculate the sum of each column
col_sums = compare_df.dropna().sum()
# L1 normalize each column
normalized_df = compare_df.dropna().div(col_sums)

normalized_df.plot.bar(rot=0, figsize=(16, 3))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Q5
#
# <font color="red">What is the problem of the above figure? Which state has more ZeroAccess attacks w.r.t its population? Can you explain why?</font>
#
# Hint: it is an open quesion.
#
# Answer:
# <font color="red">We can see that Kansas has more ZeroAccess attacks w.r.t its population from the above figure. Here are possible reasons: 1.If organizations in a region couldn't plug loopholes immediately, the attacks might happen again and again. 2.If network users in a region lack sufficient antivirus software or awareness, malware can spread throughout the region, causing widespread damage.</font>

# %% [markdown]
# # Q6
#
# Combine another dataset `c_df` by 'state'.

# %%
c_df
# Out:
#       subregion          region     pop  income   ipaddr  ufo2010
# 0     abbeville  south carolina   25101   34670    30330        2
# 1        acadia       louisiana   61912   37970    38203        6
# 2      accomack        virginia   33341   41595    41338        2
# 3           ada           idaho  409061   55304  1035427       59
# 4         adair            iowa    7481   47623     3762        0
# ...         ...             ...     ...     ...      ...      ...
# 3067       yuma         arizona  200022   41441    99991       53
# 3068       yuma        colorado   10119   44991     7662        1
# 3069     zapata           texas   14290   26009     3833        0
# 3070     zavala           texas   11961   23952      545        1
# 3071    ziebach    south dakota    2869   27917     1277        0
#
# [3072 rows x 6 columns]

# %%
feature_df = c_df.drop(['subregion'], axis=1).groupby(by='region').sum()

feature_df
# Out:
#                            pop    income     ipaddr  ufo2010
# region
# alabama                4822023   2522962   22542601      250
# arizona                6532974    612727   62062174     1250
# arkansas               2949131   2677866    4810526      265
# california            38041430   3241756  156511903     3769
# colorado               5129284   3206281   22787577      513
# connecticut            3590347    565060   40993589      280
# delaware                917092    172156   19378182       74
# district of columbia    632323     61835   10759507        1
# florida               19317568   2990011   23716071     1465
# georgia                9919945   6433814   20947043      548
# idaho                  1595728   1904783    2148449      161
# illinois              12875255   4926504   29586316     1027
# indiana                6537334   4395705   16889196      654
# iowa                   3074186   4730381    4821849      243
# kansas                 2885905   4726532    3985253      269
# kentucky               4380415   4534705    4896449      348
# louisiana              4601893   2636560    4666033      229
# maine                  1329192    718543    1541702      164
# maryland               5884563   1644061    9917917      297
# massachusetts          6646144    902542   41855676      441
# michigan               9883360   3627804   55756930      716
# minnesota              5379139   4428934   14071294      293
# mississippi            2984926   2812894    2050835       88
# missouri               6021988   4672209   18503112      489
# montana                1005141   2350772    1321791      181
# nebraska               1855525   4160090    3211714      199
# nevada                 2758931    890322    3575554      343
# new hampshire          1320718    581347    2311928      157
# new jersey             8864590   1511536   55597788      404
# new mexico             2085538   1336118    3014481      241
# new york              19570261   3318771   40624908      760
# north carolina         9752073   4171054   49536577      632
# north dakota            699628   2477562    1230751       45
# ohio                  11544225   4125406  240752799      700
# oklahoma               3814820   3191680    4400876      309
# oregon                 3899353   1616532    8134133      717
# pennsylvania          12763536   3212933   22715306      730
# rhode island           1050292    322775    1675757       74
# south carolina         4723723   1793990    5256663      336
# south dakota            833354   2884657     993783       48
# tennessee              6456243   3707515    8745681      500
# texas                 26059203  11307750   63230468     1706
# utah                   2855287   1530668    7520755      178
# vermont                 626011    718544     988910       42
# virginia               6776755   5394332   48947094      506
# washington             6897012   1900803   10886247     1073
# west virginia          1855413   2033260    1389593      172
# wisconsin              5722058   3502385    9246404      421
# wyoming                 576412   1282062    1343279       93

# %%
# copy data and change state to lowercase
# because the state name in feature_df is lowercase
compare_lower_df = compare_df.copy()
compare_lower_df = compare_lower_df.reset_index().rename(columns={"index":"state"})
compare_lower_df.state = compare_lower_df.state.apply(lambda s: s.lower() if s != "Washington, D.C." else "district of columbia")
compare_lower_df = compare_lower_df.set_index('state')
compare_lower_df
# Out:
#                       ZeroAccess  population    internet
# state
# california                 28162  37350092.0  29758896.0
# texas                      22746  25042738.0  17176661.0
# florida                    17414  18732783.0  14764418.0
# new york                   16207  19746813.0  16091772.0
# kansas                     15241   2848369.0   2248721.0
# pennsylvania               11020  12737230.0   9909482.0
# ohio                       10832  11663946.0   8949773.0
# georgia                    10386   9932505.0   7597608.0
# illinois                   10312  13046084.0  10243294.0
# north carolina              8989   9479467.0   6809315.0
# michigan                    8362  10074498.0   7899843.0
# new jersey                  8066   8799248.0   7728426.0
# arizona                     5928   6665093.0   5230474.0
# virginia                    5753   7965428.0   6193567.0
# washington                  5631   6734229.0   5772919.0
# massachusetts               5597   6662878.0   5745853.0
# missouri                    5561   6050503.0   4380156.0
# indiana                     5418   6490613.0   4770355.0
# tennessee                   5248   6362421.0   4638409.0
# maryland                    5195   5759373.0   4737650.0
# wisconsin                   4965   5714200.0   4744417.0
# alabama                     4779   4758191.0   3092273.0
# kentucky                    4504   4359450.0   2997542.0
# minnesota                   4470   5321556.0   4370006.0
# south carolina              4460   4609176.0   3086634.0
# colorado                    4413   5077553.0   4058749.0
# louisiana                   4372   4539283.0   3071973.0
# oklahoma                    3225   3725797.0   2530656.0
# connecticut                 2924   3555261.0   3074229.0
# arkansas                    2738   2919815.0   1949869.0
# oregon                      2686   3865861.0   3327971.0
# mississippi                 2600   2983018.0   1769430.0
# iowa                        2559   3039465.0   2354728.0
# nevada                      2283   2670861.0   2137074.0
# utah                        1830   2813835.0   2465247.0
# west virginia               1718   1838901.0   1296905.0
# nebraska                    1552   1815500.0   1455917.0
# new mexico                  1532   2030790.0   1380358.0
# maine                       1227   1332155.0   1102933.0
# idaho                       1147   1562046.0   1284500.0
# new hampshire               1145   1338495.0   1205558.0
# rhode island                 992   1064277.0    861596.0
# hawaii                       983         NaN         NaN
# montana                      889    985235.0    725139.0
# wyoming                      757    549990.0    436437.0
# south dakota                 750    820920.0    598832.0
# delaware                     740    894424.0    719500.0
# north dakota                 634    653642.0    496207.0
# district of columbia         621    605959.0    463503.0
# alaska                       533         NaN         NaN
# vermont                      397    628294.0    513123.0

# %%
# create final feature dataframe
# remove pop or population column
# join two dataframes
# dropna() to remove rows with missing value
# axis=1 to concat columns
# join="outer" to keep all rows

feature_df = pd.concat([feature_df, compare_lower_df], join="outer", sort=False, axis=1).dropna().drop(['pop'], axis = 1)
feature_df
# Out:
#                           income       ipaddr  ufo2010  ZeroAccess  \
# alabama                2522962.0   22542601.0    250.0        4779
# arizona                 612727.0   62062174.0   1250.0        5928
# arkansas               2677866.0    4810526.0    265.0        2738
# california             3241756.0  156511903.0   3769.0       28162
# colorado               3206281.0   22787577.0    513.0        4413
# connecticut             565060.0   40993589.0    280.0        2924
# delaware                172156.0   19378182.0     74.0         740
# district of columbia     61835.0   10759507.0      1.0         621
# florida                2990011.0   23716071.0   1465.0       17414
# georgia                6433814.0   20947043.0    548.0       10386
# idaho                  1904783.0    2148449.0    161.0        1147
# illinois               4926504.0   29586316.0   1027.0       10312
# indiana                4395705.0   16889196.0    654.0        5418
# iowa                   4730381.0    4821849.0    243.0        2559
# kansas                 4726532.0    3985253.0    269.0       15241
# kentucky               4534705.0    4896449.0    348.0        4504
# louisiana              2636560.0    4666033.0    229.0        4372
# maine                   718543.0    1541702.0    164.0        1227
# maryland               1644061.0    9917917.0    297.0        5195
# massachusetts           902542.0   41855676.0    441.0        5597
# michigan               3627804.0   55756930.0    716.0        8362
# minnesota              4428934.0   14071294.0    293.0        4470
# mississippi            2812894.0    2050835.0     88.0        2600
# missouri               4672209.0   18503112.0    489.0        5561
# montana                2350772.0    1321791.0    181.0         889
# nebraska               4160090.0    3211714.0    199.0        1552
# nevada                  890322.0    3575554.0    343.0        2283
# new hampshire           581347.0    2311928.0    157.0        1145
# new jersey             1511536.0   55597788.0    404.0        8066
# new mexico             1336118.0    3014481.0    241.0        1532
# new york               3318771.0   40624908.0    760.0       16207
# north carolina         4171054.0   49536577.0    632.0        8989
# north dakota           2477562.0    1230751.0     45.0         634
# ohio                   4125406.0  240752799.0    700.0       10832
# oklahoma               3191680.0    4400876.0    309.0        3225
# oregon                 1616532.0    8134133.0    717.0        2686
# pennsylvania           3212933.0   22715306.0    730.0       11020
# rhode island            322775.0    1675757.0     74.0         992
# south carolina         1793990.0    5256663.0    336.0        4460
# south dakota           2884657.0     993783.0     48.0         750
# tennessee              3707515.0    8745681.0    500.0        5248
# texas                 11307750.0   63230468.0   1706.0       22746
# utah                   1530668.0    7520755.0    178.0        1830
# vermont                 718544.0     988910.0     42.0         397
# virginia               5394332.0   48947094.0    506.0        5753
# washington             1900803.0   10886247.0   1073.0        5631
# west virginia          2033260.0    1389593.0    172.0        1718
# wisconsin              3502385.0    9246404.0    421.0        4965
# wyoming                1282062.0    1343279.0     93.0         757
#
#                       population    internet
# alabama                4758191.0   3092273.0
# arizona                6665093.0   5230474.0
# arkansas               2919815.0   1949869.0
# california            37350092.0  29758896.0
# colorado               5077553.0   4058749.0
# connecticut            3555261.0   3074229.0
# delaware                894424.0    719500.0
# district of columbia    605959.0    463503.0
# florida               18732783.0  14764418.0
# georgia                9932505.0   7597608.0
# idaho                  1562046.0   1284500.0
# illinois              13046084.0  10243294.0
# indiana                6490613.0   4770355.0
# iowa                   3039465.0   2354728.0
# kansas                 2848369.0   2248721.0
# kentucky               4359450.0   2997542.0
# louisiana              4539283.0   3071973.0
# maine                  1332155.0   1102933.0
# maryland               5759373.0   4737650.0
# massachusetts          6662878.0   5745853.0
# michigan              10074498.0   7899843.0
# minnesota              5321556.0   4370006.0
# mississippi            2983018.0   1769430.0
# missouri               6050503.0   4380156.0
# montana                 985235.0    725139.0
# nebraska               1815500.0   1455917.0
# nevada                 2670861.0   2137074.0
# new hampshire          1338495.0   1205558.0
# new jersey             8799248.0   7728426.0
# new mexico             2030790.0   1380358.0
# new york              19746813.0  16091772.0
# north carolina         9479467.0   6809315.0
# north dakota            653642.0    496207.0
# ohio                  11663946.0   8949773.0
# oklahoma               3725797.0   2530656.0
# oregon                 3865861.0   3327971.0
# pennsylvania          12737230.0   9909482.0
# rhode island           1064277.0    861596.0
# south carolina         4609176.0   3086634.0
# south dakota            820920.0    598832.0
# tennessee              6362421.0   4638409.0
# texas                 25042738.0  17176661.0
# utah                   2813835.0   2465247.0
# vermont                 628294.0    513123.0
# virginia               7965428.0   6193567.0
# washington             6734229.0   5772919.0
# west virginia          1838901.0   1296905.0
# wisconsin              5714200.0   4744417.0
# wyoming                 549990.0    436437.0

# %% [markdown]
# ## Q7
#
# Now we can <font color="red">perform linear regression, and explain the results.</font>
#
#
# Set $X$ be `["population", "income", "ipaddr", "ufo2010", "internet"]`,
# let $y$ be `ZeroAccess`.

# %%
X_train = feature_df[["population", "income", "ipaddr", "ufo2010", 'internet']]
y_train = feature_df['ZeroAccess']

# %%
from sklearn.linear_model import LinearRegression
linearRegModel = LinearRegression()
linearRegModel.fit(X_train, y_train)

print("Intercept is ", linearRegModel.intercept_)
print("coefficients  is ", linearRegModel.coef_)
# Out:
# Intercept is  -207.76887623992843
# coefficients  is  [ 4.72217202e-04  4.49180000e-04  4.75719076e-07 -2.83257931e-01
#   3.68395519e-04]

# %%
# print with feature name
print()
print("ZeroAccess = ")
for c,f in zip(linearRegModel.coef_, X_train.columns):
  print(' {0:+} * {1}'.format(c, f))
print("", linearRegModel.intercept_)
# Out:
# ZeroAccess =
#  +0.0004722172018320858 * population
#  +0.0004491799997903721 * income
#  +4.757190756162769e-07 * ipaddr
#  -0.2832579305946884 * ufo2010
#  +0.0003683955186800406 * internet
#  -207.76887623992843

# %% [markdown]
# Q8
#
# Now we can <font color="red">perform linear regression with StandardScaler, and explain the results.</font>

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)

# %%
nolinearRegModel = LinearRegression()
nolinearRegModel.fit(scaled_X_train, y_train)

print("Intercept is ", nolinearRegModel.intercept_)
print("coefficients  is ", nolinearRegModel.coef_)

print()
print("ZeroAccess = ")
for c,f in zip(nolinearRegModel.coef_, X_train.columns):
  print(' {0:+} * {1}'.format(c, f))
print("", nolinearRegModel.intercept_)
# Out:
# Intercept is  5693.408163265306
# coefficients  is  [3230.75776632  883.77156561   19.56772197 -169.26019045 1962.55761927]
#
# ZeroAccess =
#  +3230.757766322388 * population
#  +883.7715656071578 * income
#  +19.567721972321213 * ipaddr
#  -169.26019044995533 * ufo2010
#  +1962.5576192668668 * internet
#  5693.408163265306
